# %%
#!pip install bs4
#!pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get("https://en.wikipedia.org/wiki/Main_Page")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# ...

# %%
page

# %%
#get the response of 200 now we can get the data from

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Wikipedia, the free encyclopedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"a9f954a0-9418-4077-bdee-5a8bce8a5cba","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Main_Page","wgTitle":"Main Page","wgCurRevisionId":1004593520,"wgRevisionId":1004593520,"wgArticleId":15580374,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Main_Page","wgRelevantArticleId":15580374,"wgIsProbablyEditable":!1,"wgRel
# ...

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
print(soup.prettify()) # for maintin indentation
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Wikipedia, the free encyclopedia
#   </title>
#   <script>
# ...

# %%
headerTag = soup.find_all(['h1','h2','h3','h4','h5','h6'])

# %%
headerTag
# Out:
# [<h1 class="firstHeading" id="firstHeading">Main Page</h1>,
#  <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>,
#  <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>,
#  <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>,
#  <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>,
#  <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>,
#  <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>,
# ...

# %% [raw]
# #2. Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. Name, IMDB rating, Year of release) and make data frame.

# %%
page_Imdb = requests.get("https://www.imdb.com/chart/top")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# ...

# %%
page_Imdb

# %%
soup=BeautifulSoup(page_Imdb.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
raw_html=soup.find('tbody',{'class':'lister-list'}).findAll('tr')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-472-63e48492df47> in <module>
# ----> 1 raw_html=soup.find('tbody',{'class':'lister-list'}).findAll('tr')
#
# AttributeError: 'NoneType' object has no attribute 'findAll'

# %%
movielist=[]
for html in range(0,len(raw_html)):
    Name=raw_html[html].find('td',{'class','titleColumn'}).find('a').get_text(),
    rating=raw_html[html].find('td',{'class':'ratingColumn imdbRating'}).find('strong').get_text(),
    year = raw_html[html].find('td',{'class':'titleColumn'}).find('span').get_text()
    if(html<=100):
        data={
            "Name":Name,
            "rating":rating,
            "year":year
        }
        movielist.append(data)

# %%
import pandas as pd
data=pd.DataFrame(movielist)
data

# %%
data

# %% [markdown]
# #### Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. Name, IMDB rating, Year of release) and make data frame.

# %%
page_ind=requests.get("https://www.imdb.com/india/top-rated-indian-movies/")

# %%
page_ind

# %%
soup=BeautifulSoup(page_ind.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
ind_mov=soup.find('tbody',{'class':'lister-list'}).findAll('tr')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-474-37585d92c3d8> in <module>
# ----> 1 ind_mov=soup.find('tbody',{'class':'lister-list'}).findAll('tr')
#
# AttributeError: 'NoneType' object has no attribute 'findAll'

# %%
ind_mov
# Out:
# [<tr>
#  <td class="posterColumn">
#  <span data-value="1" name="rk"></span>
#  <span data-value="8.505543525926456" name="ir"></span>
#  <span data-value="-4.529088E11" name="us"></span>
#  <span data-value="25361" name="nv"></span>
#  <span data-value="-2.4944564740735444" name="ur"></span>
#  <a href="/title/tt0048473/"> <img alt="Pather Panchali" height="67" src="https://m.media-amazon.com/images/M/MV5BNDE5YmMxYjEtZjNjNC00NjM2LWE2ZjctOTkyNGMxODRiMGNiXkEyXkFqcGdeQXVyNTgyNTA4MjM@._V1_UY67_CR1,0,45,67_AL_.jpg" width="45"/>
#  </a> </td>
#  <td class="titleColumn">
#        1.
#        <a href="/title/tt0048473/" title="Satyajit Ray (dir.), Kanu Bannerjee, Karuna Bannerjee">Pather Panchali</a>
#  <span class="secondaryInfo">(1955)</span>
#  </td>
#  <td class="ratingColumn imdbRating">
#  <strong title="8.5 based on 25,361 user ratings">8.5</strong>
#  </td>
#  <td class="ratingColumn">
#  <div class="seen-widget seen-widget-tt0048473 pending" data-titleid="tt0048473">
# ...

# %%
indian_movie=[]
for html in range(len(ind_mov)):
    if(html<=100):
        
        Name = ind_mov[html].find('td',{'class':'titleColumn'}).find('a').get_text(),
        Year_of_Release=ind_mov[html].find('td',{'class':'titleColumn'}).find('span').get_text(),
        Rating =ind_mov[html].find('td',{'class':'ratingColumn imdbRating'}).find('strong').get_text()
        data={
           'Name' :Name,
           'Year_of_Release':Year_of_Release,
           'Rating':Rating 
        }
        indian_movie.append(data)

# %%
indian_movie=pd.DataFrame(indian_movie)

# %%
indian_movie
# Out:
#                             Name Year_of_Release Rating
# 0             (Pather Panchali,)       ((1955),)    8.5
# 1                     (Nayakan,)       ((1987),)    8.5
# 2           (Pariyerum Perumal,)       ((2018),)    8.5
# 3                  (Anbe Sivam,)       ((2003),)    8.5
# 4                     (Golmaal,)       ((1979),)    8.5
# ..                           ...             ...    ...
# 96   (Uri: The Surgical Strike,)       ((2018),)    8.1
# 97                  (Virumandi,)       ((2004),)    8.1
# 98                         (PK,)       ((2014),)    8.1
# 99                      (Lucia,)       ((2013),)    8.1
# 100                     (Iqbal,)       ((2005),)    8.1
#
# [101 rows x 3 columns]

# %% [markdown]
# #### 4. Write a python program to scrap book name, author name, genre and book review of any 5 books from ‘www.bookpage.com’

# %%
books= requests.get("https://bookpage.com/reviews")
review = requests.get('https://bookpage.com/reviews/26344-casey-mcquiston-one-last-stop-romance#.YLfSJtUzbIU')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# ...

# %%
books
review

# %%
soup =BeautifulSoup(books.text,'html.parser')

# %%
soup

# %%
getData = soup.findAll('div',{'class':'flex-article-content'})

# %%
getData

# %%
books =[]
for i in range(0,len(getData)):
    if(i<=5):
        data={
           'BookName' : getData[i].find('h4',{'class':'italic'}).find('a').get_text(),
           'AuthorName' : getData[i].find('p',{'class':'sans bold'}).get_text().replace("\n",''),
           'Genre' : getData[i].find('p',{'class':'genre-links hidden-phone'}).find('a').get_text()
        }
        books.append(data)
        print(books)

# %%
df=pd.DataFrame(books)
df

# %% [markdown]
# #### Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’.

# %%
#Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
Odi = requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')
Odi

# %%
soup = BeautifulSoup(Odi.text,'html.parser')

# %%
soup.find

# %%
getData = soup.find('tbody').findAll('tr')

# %%
getData

# %%
mtach_stats=[]
for i in range(1,len(getData)):
    if(i<=10):
        data ={
            'Match':getData[i].find('td',{'class':'table-body__cell u-center-text'}).get_text(),
            'points':getData[i].find('td',{'class':'table-body__cell u-center-text'}).get_text(),
            'rating':getData[i].find('td',{'class':'table-body__cell u-text-right rating'}).get_text(),
        }
        mtach_stats.append(data)

# %%
df=pd.DataFrame(mtach_stats)

# %%
df

# %%
#Top 10 ODI Batsmen in men along with the records of their team and rating.

Batsman = requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting')
Batsman

# %%
soup1=BeautifulSoup(Batsman.text,'html.parser')
soup1

# %%
getTrData = soup1.findAll('tr',{'class':'table-body'})

# %%
getTrData

# %%
batsman_data=[]
for i in range (1,len(getTrData)):
    if(i<=10):
        data={
            'Batsmen':getTrData[i].find('td',{'class':'table-body__cell rankings-table__name name'}).find('a').get_text(),
            'Team Name':getTrData[i].find('span',{'class':'table-body__logo-text'}).get_text(),
            'Rating':getTrData[i].find('td',{'class':'table-body__cell rating'}).get_text()
        }
        
        batsman_data.append(data)

# %%
batsman_data

# %%
df=pd.DataFrame(batsman_data)
df

# %%
DataSet = requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling')

DataSet

# %%
soup = BeautifulSoup(DataSet.text,'html.parser')

# %%
soup

# %%
getTrData = soup.findAll('tr',{'class':'table-body'})

# %%
getTrData

# %%
#Top 10 ODI bowlers along with the records of their team and rating.
bowlerData =[]
for i in range (1,len(getTrData)):
    if(i<=10):
        data={
            'Bowler':getTrData[i].find('td',{'class':'table-body__cell rankings-table__name name'}).find('a').get_text(),
            'Team':getTrData[i].find('span',{'class':'table-body__logo-text'}).get_text(),
            'Rating':getTrData[i].find('td',{'class':'table-body__cell rating'}).get_text(),
        }
        
        bowlerData.append(data)

# %%
df=pd.DataFrame(bowlerData)

# %%
df

# %%
#Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.
womenUrl = requests.get('https://www.icc-cricket.com/rankings/womens/team-rankings/odi')

# %%
womenUrl

# %%
soup=BeautifulSoup(womenUrl.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
getWomenData = soup.findAll('tr',{'class':'table-body'})

# %%
getWomenData
# Out:
# []

# %%
womens_team=[]
for i in range(1,len(getWomenData)):
    if(i<=10):
        data={
            'Team':getWomenData[i].find('span',{'class':'u-hide-phablet'}).get_text(),
            'Matches':getWomenData[i].find('td',{'class':'table-body__cell u-center-text'}).get_text(),
            'point':getWomenData[i].find('td',{'class':'table-body__cell u-center-text'}).get_text(),
            'rating':getWomenData[i].find('td',{'class':'table-body__cell u-text-right rating'}).get_text()
        }
        womens_team.append(data)

# %%
df=pd.DataFrame(womens_team)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
PlayersUrl = requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# ...

# %%
PlayersUrl

# %%
soup=BeautifulSoup(PlayersUrl.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
getPlayerData = soup.findAll('tr','table-body')

# %%
getPlayerData
# Out:
# []

# %%
players=[]
for i in range(1,len(getPlayerData)):
    if(i<=10):
        data={
            'Players':getPlayerData[i].find('td','table-body__cell rankings-table__name name').find('a').get_text(),
            'Team':getPlayerData[i].find('span','table-body__logo-text').get_text(),
            'Rating':getPlayerData[i].find('td','table-body__cell rating').get_text()
        }
        players.append(data)

# %%
df=pd.DataFrame(players)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Top 10 women’s ODI all-rounder along with the records of their team and rating.
AllRounderUrl = requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder')
AllRounderUrl
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# ...

# %%
soup=BeautifulSoup(AllRounderUrl.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
getAllRounderData = soup.findAll('tr',{'class':'table-body'})

# %%
getAllRounderData
# Out:
# []

# %%
AllRounder=[]
for i in range(0,len(getAllRounderData)):
    if(i<=10):
        data ={
            'All-Rounder-Player':getAllRounderData[i].find('td',{'class':'table-body__cell rankings-table__name name'}).find('a').get_text(),
            'Team':getAllRounderData[i].find('span',{'class':'table-body__logo-text'}).get_text(),
            'Rating':getAllRounderData[i].find('td',{'class':'table-body__cell rating'}).get_text()
        }
        AllRounder.append(data)

# %%
df=pd.DataFrame(AllRounder)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
amazonUrl = requests.get('https://www.amazon.in/s?k=mobiles&rh=n%3A976419031%2Cp_n_price%3A1318506031&nav_sdd=aps&pd_rd_r=2efd5315-0e8e-4bcf-98a1-ea004ad212c8&pd_rd_w=qd0MZ&pd_rd_wg=aw01L&pf_rd_p=f0a2462c-b863-42f6-aa10-7bf0a4ea1595&pf_rd_r=KARWF00Y1DA4G0XNDNB5&qid=1622742648&ref=sxts_sxts_ref_scx_alster_3');
amazonUrl
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# ...

# %%
soup=BeautifulSoup(amazonUrl.text,'html.parser')
soup

# %%
getMobData = soup.findAll('div','a-section a-spacing-medium')

# %%
getMobData

# %%
len(getMobData)

# %%
data1 =[]
for i in range(0,len(getMobData)):
    if(i<=10):
        data={
            'Product Name':getMobData[i].find('span',{'class':'a-size-medium a-color-base a-text-normal'}).get_text(),
            'Product Price':getMobData[i].find('span','a-offscreen').get_text(),
            'Rating':getMobData[i].find('span', "a-icon-alt").get_text(),
            'Url':getMobData[i].find('img',{'class':'s-image'}).get('srcset')
        }
        data1.append(data)

# %%
df=pd.DataFrame(data1)

# %%
df

# %%
getWeatherUrl = requests.get('https://forecast.weather.gov/MapClick.php?lat=37.777120000000025&lon=-122.41963999999996#.YLkgjtUzbIU')

# %%
getWeatherUrl

# %%
soup = BeautifulSoup(getWeatherUrl.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
getData = soup.findAll('div','tombstone-container')

# %%
getData
# Out:
# []

# %%
len(getData)
# Out:
# 0

# %%
weather=[]
for i in range(len(getData)):
    data={
       'Period': getData[i].find('p','period-name').get_text(),
       'Desc': getData[i].find('p','short-desc').get_text(),
       'Temp and Description': getData[i].find('p','temp').get_text()
    }
    weather.append(data)

# %%
df=pd.DataFrame(weather)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
getFresher = requests.get('https://internshala.com/fresher-jobs')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# ...

# %%
getFresher

# %%
soup = BeautifulSoup(getFresher.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
getFresherData = soup.findAll('div',{'class':'internship_meta'})

# %%
getFresherData
# Out:
# []

# %%
len(getFresherData)
# Out:
# 0

# %%
def Internshala(url):
    p9 = requests.get(url)
    #p9.content
    print(p9.status_code)
    
    s9 = BeautifulSoup(p9.content, "html.parser")
    #print(s9.prettify())
    
    title = []
    company = []
    ctc = []
    apply_date = []
    
    temp = []
    
    get_titles = s9.find_all('div',class_ = "heading_4_5 profile")   
    get_companies = s9.find_all('a', class_ = 'link_display_like_text')
    get_ctcadate = s9.find_all('div',class_ = "item_body", id = False)
    
    for cdate in get_ctcadate:
        temp.append(cdate)
        
    for t, c in zip(get_titles, get_companies):
        title.append(t.text.strip())
        company.append(c.text.strip())
    
    for i in temp:
        ctc.append(i) if 'LPA' in i else apply_date.append(i)
        
    Internshala = pd.DataFrame({
         'Title': title,
          'Company': company,
#          'Apply date':temp,
         })
    print("Shape of dataset is {} rows and {} columns".format(*Internshala.shape))
    print(Internshala.head())
    #print(temp)

# %%
Internshala("https://internshala.com/fresher-jobs")
# Out:
# 200
# Shape of dataset is 40 rows and 2 columns
#                                Title                        Company
# 0            PHP & LARAVEL DEVELOPER                     Nyx Wolves
# 1  Backend Developer (Ruby On Rails)  Wollfish Labs Private Limited
# 2        Customer Service Specialist                       Wono Inc
# 3                   Graphic Designer                       Wono Inc
# 4       Digital Marketing Specialist                       Wono Inc
