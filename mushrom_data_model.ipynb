# %% [markdown]
# #Descrption of dataset -: Data Set Information: This data set includes descriptions of hypothetical samples corresponding to 23 species of gilled mushrooms in the Agaricus and Lepiota Family (pp. 500-525). Each species is identified as definitely edible, definitely poisonous, or of unknown edibility and not recommended. This latter class was combined with the poisonous one. The Guide clearly states that there is no simple rule for determining the edibility of a mushroom; no rule like ``leaflets three, let it be'' for Poisonous Oak and Ivy.

# %% [markdown]
# import the basic libraries like numpy/ panda /seaborn and others

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# load data set

# %%
mus_df=pd.read_csv('mushrooms_data.csv');
mus_df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %% [markdown]
# show first 5 rows

# %%
mus_df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %% [markdown]
# last row

# %%
mus_df.tail()
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %% [markdown]
# # EDA

# %%
mus_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %% [markdown]
# Describe method show the details of dataset its show mean/median/mode and also show is there null value or missing value

# %%
mus_df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# ...

# %% [markdown]
# check null value in each column

# %%
mus_df.isnull()
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises   odor  \
# 0     False      False        False      False    False  False
# 1     False      False        False      False    False  False
# 2     False      False        False      False    False  False
# 3     False      False        False      False    False  False
# 4     False      False        False      False    False  False
# ...     ...        ...          ...        ...      ...    ...
# 8119  False      False        False      False    False  False
# 8120  False      False        False      False    False  False
# 8121  False      False        False      False    False  False
# 8122  False      False        False      False    False  False
# 8123  False      False        False      False    False  False
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0               False         False      False       False  ...
# 1               False         False      False       False  ...
# ...

# %% [markdown]
# check sum of all the null value

# %%
mus_df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# no null value is found

# %% [markdown]
# # visualization

# %%
sns.heatmap(mus_df.isnull())
# Out:
# <AxesSubplot:>

# %%
mus_df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %% [markdown]
# Univariate Analysis

# %%
col=['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']

for col in mus_df:
   
    sns.histplot(mus_df[col],kde=True)
    plt.show()

# %% [markdown]
# Divide the dataset into features and target

# %%
x=mus_df.drop(['class'],axis=True)
y=mus_df['class']

# %%
x
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0            x           s         n       t    p               f
# 1            x           s         y       t    a               f
# 2            b           s         w       t    l               f
# 3            x           y         w       t    p               f
# 4            x           s         g       f    n               f
# ...        ...         ...       ...     ...  ...             ...
# 8119         k           s         n       f    n               a
# 8120         x           s         n       f    n               a
# 8121         f           s         n       f    n               a
# 8122         k           y         n       f    y               f
# 8123         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0               c         n          k           e  ...
# 1               c         b          k           e  ...
# ...

# %%
y
# Out:
# 0       p
# 1       e
# 2       e
# 3       p
# 4       e
#        ..
# 8119    e
# 8120    e
# 8121    e
# 8122    p
# 8123    e
# Name: class, Length: 8124, dtype: object

# %%
for col in x:
   
    sns.countplot(mus_df[col])
    plt.show()

# %%
sns.countplot(y) # target data
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
y.value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %% [markdown]
# balance in class not much difference is there between two classes

# %% [markdown]
# preprocessing

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for col in mus_df:
    mus_df[col]=le.fit_transform(mus_df[col])

# %% [markdown]
# Dataset after encoding with Label Encoder

# %%
mus_df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
mus_df.shape
# Out:
# (8124, 23)

# %% [markdown]
# there are 8124 rows and 23 columns

# %% [markdown]
# divide the class and feture columns after encoding

# %%
x=mus_df.drop('class',axis=1)
y=mus_df['class']

# %%
x
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             5            2          4        1     6                1
# 1             5            2          9        1     0                1
# 2             0            2          8        1     3                1
# 3             5            3          8        1     6                1
# 4             5            2          3        0     5                1
# ...         ...          ...        ...      ...   ...              ...
# 8119          3            2          4        0     5                0
# 8120          5            2          4        0     5                0
# 8121          2            2          4        0     5                0
# 8122          3            3          4        0     8                1
# 8123          5            2          4        0     5                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Name: class, Length: 8124, dtype: int32

# %%
mus_df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# after encoding no null value

# %%
col=['cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
       'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
       'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
       'stalk-surface-below-ring', 'stalk-color-above-ring',
       'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
       'ring-type', 'spore-print-color', 'population', 'habitat']
for col in x:
    sns.boxplot(x[col])
    plt.show()

# %% [markdown]
# Population found ouliers gill-attachment\gill-spacing one single ouliers is found stalk-root - more than one outliers far away from viscous is seen stalk-color-above-ring - many ouliers is to see as same in stalk-color-below-ring viel-color/ring-number/population also outlies get to see

# %% [markdown]
# Bivariate Analysis

# %%
plt.title('Comparision between cap-shape and cap-surface')
sns.scatterplot(mus_df['cap-shape'],mus_df['cap-surface'],hue=mus_df['class'])
plt.show()

# %%
plt.title('Comparision between cap-color and cap-surface')
sns.scatterplot(mus_df['cap-color'],mus_df['bruises'],hue=mus_df['class'])
plt.show()

# %%
plt.title('Comparision between population and habitat')
sns.scatterplot(mus_df['population'],mus_df['habitat'],hue=mus_df['class'])
plt.show()

# %%
plt.title('Comparision between stalk-shape and stalk-root')
sns.scatterplot(mus_df['stalk-shape'],mus_df['stalk-root'],hue=mus_df['class'])
# Out:
# <AxesSubplot:title={'center':'Comparision between stalk-shape and stalk-root'}, xlabel='stalk-shape', ylabel='stalk-root'>

# %%
plt.title('Comparision between veil-type and veil-color')
sns.scatterplot(mus_df['veil-type'],mus_df['veil-color'],hue=mus_df['class'])
# Out:
# <AxesSubplot:title={'center':'Comparision between veil-type and veil-color'}, xlabel='veil-type', ylabel='veil-color'>

# %%
plt.title('Comparision between gill-size and gill-color')
sns.scatterplot(mus_df['gill-size'],mus_df['gill-color'],hue=mus_df['class'])
# Out:
# <AxesSubplot:title={'center':'Comparision between gill-size and gill-color'}, xlabel='gill-size', ylabel='gill-color'>

# %% [markdown]
# Above plot show the categorial data to represntation and from scatter plot not much to identify

# %%
sns.pairplot(mus_df,hue=['class'])

# %%
cor=mus_df.corr()
cor
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(cor,annot=True)
plt.show()

# %% [markdown]
# # Model/Training

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %% [markdown]
# Finding best Random State

# %%
from sklearn.tree import DecisionTreeClassifier
maxAcc=0
maxRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=i)
    DT=DecisionTreeClassifier()
    DT.fit(x_train,y_train)
    pred=DT.predict(x_test)
    accu=accuracy_score(y_test,pred)
    if accu>maxAcc:
        maxAcc=accu
        maxRs=1
print("Best accuracy -",maxAcc,'Best Random state = ',maxRs)
# Out:
# Best accuracy - 1.0 Best Random state =  1

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
DTC=DecisionTreeClassifier()
DTC.fit(x_train,y_train)
pred=DTC.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)
confusion_matrix = confusion_matrix(y_test,pred)
print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
print('confusion Matrix :', confusion_matrix)
# Out:
# Accuracy Score : 1.0
# Classification Score :               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1365
#            1       1.00      1.00      1.00      1316
#
#     accuracy                           1.00      2681
#    macro avg       1.00      1.00      1.00      2681
# weighted avg       1.00      1.00      1.00      2681
#
# confusion Matrix : [[1365    0]
#  [   0 1316]]

# %% [markdown]
# DTC = 100 %

# %%
RF=RandomForestClassifier(n_estimators=100)
RF.fit(x_train,y_train)
pred=RF.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)

print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
# Out:
# Accuracy Score : 1.0
# Classification Score :               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1365
#            1       1.00      1.00      1.00      1316
#
#     accuracy                           1.00      2681
#    macro avg       1.00      1.00      1.00      2681
# weighted avg       1.00      1.00      1.00      2681

# %% [markdown]
# AD=100%

# %%
AD=AdaBoostClassifier(n_estimators=100)
AD.fit(x_train,y_train)
pred=AD.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)

print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
# Out:
# Accuracy Score : 1.0
# Classification Score :               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1365
#            1       1.00      1.00      1.00      1316
#
#     accuracy                           1.00      2681
#    macro avg       1.00      1.00      1.00      2681
# weighted avg       1.00      1.00      1.00      2681

# %%
SV=SVC()
SV.fit(x_train,y_train)
pred=SV.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)

print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
# Out:
# Accuracy Score : 0.9865721745617307
# Classification Score :               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      1365
#            1       1.00      0.97      0.99      1316
#
#     accuracy                           0.99      2681
#    macro avg       0.99      0.99      0.99      2681
# weighted avg       0.99      0.99      0.99      2681

# %%
LG=LogisticRegression()
LG.fit(x_train,y_train)
pred=LG.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)

print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
# Out:
# Accuracy Score : 0.9526296158149944
# Classification Score :               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95      1365
#            1       0.96      0.95      0.95      1316
#
#     accuracy                           0.95      2681
#    macro avg       0.95      0.95      0.95      2681
# weighted avg       0.95      0.95      0.95      2681

# %%
gnb=GaussianNB()
gnb.fit(x_train,y_train)
pred=gnb.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)

print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
# Out:
# Accuracy Score : 0.917195076464006
# Classification Score :               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92      1365
#            1       0.91      0.92      0.92      1316
#
#     accuracy                           0.92      2681
#    macro avg       0.92      0.92      0.92      2681
# weighted avg       0.92      0.92      0.92      2681

# %% [markdown]
# Checking Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
print('Decission Tree :',cross_val_score(DTC,x,y,cv=5).mean())
# Out:
# Decission Tree : 0.9275962106858658

# %%
print('Random Forest :',cross_val_score(RF,x,y,cv=5).mean())
# Out:
# Random Forest : 0.8966943539219402

# %%
print('Adaboost Tree  :',cross_val_score(AD,x,y,cv=5).mean())
# Out:
# Adaboost Tree  : 0.9108568397120121

# %%
print('gaussianNB :',cross_val_score(gnb,x,y,cv=5).mean())
# Out:
# gaussianNB : 0.7259685486926866

# %%
print('Logistic Regression: ',cross_val_score(LG,x,y,cv=5).mean())
# Out:
# Logistic Regression:  0.8389792345585448

# %%
print('Support Vector :',cross_val_score(SV,x,y,cv=5).mean())
# Out:
# Support Vector : 0.841292231906025

# %% [markdown]
# HYPERPERAMETER TUNNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter ={'max_depth':np.arange(2,10),
           'criterion':['gini', 'entropy'],
           'splitter':['best','random']}

# %%
GCV=GridSearchCV(DecisionTreeClassifier(),parameter,cv=5)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                          'splitter': ['best', 'random']})

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 7, 'splitter': 'best'}

# %% [markdown]
# Best Parameter

# %%
Final_model=DecisionTreeClassifier(criterion='gini',max_depth=7,splitter='best')
Final_model.fit(x_train,y_train)
pred=Final_model.predict(x_test)
accu=accuracy_score(y_test,pred)
print(accu*100)
# Out:
# 100.0

# %% [markdown]
# # Saving the Model

# %%
import joblib
joblib.dump(Final_model,'Final_model.pkl')
# Out:
# ['Final_model.pkl']
