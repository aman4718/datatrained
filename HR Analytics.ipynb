# %% [markdown]
# #### Load Basic Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Load Data set

# %%
df=pd.read_csv("hranalytics.csv")

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# #### EDA(Exploratory Data Analysis)

# %% [markdown]
# #### load Data type information of Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# #### see the shape of dataset

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# #### load statistical summary

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# #### check Null value Present in data

# %%
df.isnull()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
##### data types
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# #### few columns are in catgorical form have to handle them with encoding technique

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#### check the empty value
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
##### check for null/missing value
df.isnull().values.any()
# Out:
# False

# %%
##### Number of counts that left the company and stayed in company
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
##### only one value is present so if it can be drop it not effect the dataset
df['StandardHours'].unique()
# Out:
# array([80], dtype=int64)

# %%
#### it is target columns having two values in form of yes and NO
df['Attrition'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
df['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
df['EducationField'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
#### it can also be droped it will not effect the dataset
df['EmployeeCount'].unique()
# Out:
# array([1], dtype=int64)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['JobRole'].unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
#### it can also be drop it will not effect the data
df['Over18'].unique()
# Out:
# array(['Y'], dtype=object)

# %%
df['OverTime'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# #### Visualization

# %%
plt.figure(figsize=(22,6))
sns.countplot(x='Age',hue='Attrition',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# #### 34 to 36 Age Employee shows they are stayed in company more
# #### 26,28,29 Age of people left the company more

# %%
sns.countplot(x='BusinessTravel',hue='Attrition',data=df)
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %% [markdown]
# #### most of emplyee left  taravel more than No Level

# %%
plt.figure(figsize=(22,7))
sns.countplot(df['DailyRate'])
# Out:
# <AxesSubplot:xlabel='DailyRate', ylabel='count'>

# %%
sns.countplot(x='JobLevel',hue='Attrition',data=df)
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='count'>

# %% [markdown]
# #### yes have less job level than No

# %% [markdown]
# #### It show the job level count

# %%
sns.countplot(x='Department',hue='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %% [markdown]
# #### age from 30 to 35 is in Research & Delvelopment Deaprtment

# %%
sns.countplot(x='Department',hue='Attrition',data=df)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %% [markdown]
# #### Employee syated in company mostly in Research & Delvelopment Deaprtment and Very least employee stayed in Human Resorce

# %%
#### number of companyies that left and stayed in company
sns.countplot(df['Attrition'])
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# #### 237 employee leftthe company and also class imbalnce is there ..

# %%
sns.scatterplot(df['Age'],df['DailyRate'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='DailyRate'>

# %% [markdown]
# #### ALL Age wise Employee have DailyRate

# %%
sns.scatterplot(df['Age'],df['EmployeeNumber'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='EmployeeNumber'>

# %% [markdown]
# #### Between 30 to 40 Age Have Employee Number is More

# %% [markdown]
# #### show Is null

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### preprocessing and Data Clean

# %% [markdown]
# #### Remove unwanted columns

# %%
df.drop(['EmployeeCount'],axis=1,inplace=True)

# %%
df.drop(['Over18'],axis=1,inplace=True)
df.drop(['StandardHours'],axis=1,inplace=True)

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeNumber  \
# ...

# %%
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
# ...

# %%
plt.figure(figsize=(22,14))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Job Level with Total Working Years is 78%
# #### Montly Income with Total Working Years is 78%
# #### percentage Rating with Performance rating is 77%

# %% [markdown]
# #### showing in corelation matrix

# %% [markdown]
# #### Divide the label and Traget Columns

# %%
x=df.drop('Attrition',axis=1)

# %%
y=df['Attrition']

# %%
#### let balance the class
from imblearn.over_sampling import RandomOverSampler
from collections import Counter
ros=RandomOverSampler(random_state=42)
x_over,y_over=ros.fit_resample(x,y)
print('Print Original Dataset',Counter(y))
print('Print Original Dataset',Counter(y_over))
# Out:
# Print Original Dataset Counter({'No': 1233, 'Yes': 237})
# Print Original Dataset Counter({'Yes': 1233, 'No': 1233})

# %% [markdown]
# ##### transformation of non numeric value

# %% [markdown]
# #### Use label Encoder for non numeric columns

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
for i in df:
    if df[i].dtype==np.number:
        continue
    df[i]=LE.fit_transform(df[i])

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      23          1               2        624           2                 0
# 1      31          0               1        113           1                 7
# 2      19          1               2        805           1                 1
# 3      15          0               1        820           1                 2
# 4       9          0               2        312           1                 1
# ...   ...        ...             ...        ...         ...               ...
# 1465   18          0               1        494           1                22
# 1466   21          0               2        327           1                 5
# 1467    9          0               2         39           1                 3
# 1468   31          0               1        579           2                 1
# 1469   16          0               2        336           1                 7
#
# ...

# %%
##### let check and Remove the Outliers shown using boxplot
for i in df:
    sns.boxplot(df[i])
    plt.show()

# %%
for i in df:
    sns.kdeplot(df[i])
    plt.show()

# %%
X=df.drop('Attrition',axis=1)

# %%
import sklearn
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[0.4463504 , 2.28090588, 0.59004834, ..., 0.0632959 , 0.67914568,
#         0.24583399],
#        [1.32236521, 0.4384223 , 0.91319439, ..., 0.76499762, 0.36871529,
#         0.80654148],
#        [0.008343  , 2.28090588, 0.59004834, ..., 1.16768726, 0.67914568,
#         1.15593471],
#        ...,
#        [1.08667552, 0.4384223 , 0.59004834, ..., 0.61549158, 0.67914568,
#         0.31487349],
#        [1.32236521, 0.4384223 , 0.91319439, ..., 0.48889978, 0.67914568,
#         1.08689522],
#        [0.32016256, 0.4384223 , 0.59004834, ..., 0.33939374, 0.36871529,
#         0.59522723]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  28,   45,   62,   62,   63,   64,   85,   98,   98,  110,  123,
#         123,  123,  126,  126,  126,  153,  178,  187,  187,  190,  190,
#         218,  231,  231,  237,  237,  270,  270,  281,  326,  386,  386,
#         401,  411,  425,  425,  427,  445,  466,  473,  477,  535,  561,
#         561,  584,  592,  595,  595,  595,  616,  624,  635,  653,  653,
#         677,  686,  701,  716,  746,  749,  752,  799,  838,  861,  861,
#         875,  875,  894,  914,  914,  918,  922,  926,  926,  937,  956,
#         962,  976,  976, 1008, 1024, 1043, 1078, 1078, 1086, 1086, 1093,
#        1111, 1116, 1116, 1135, 1138, 1138, 1156, 1184, 1221, 1223, 1242,
#        1295, 1301, 1301, 1303, 1327, 1331, 1348, 1351, 1401, 1414, 1430],
#       dtype=int64), array([31, 30, 28, 30, 29, 30, 25, 25, 28, 30, 29, 30, 31, 25, 28, 30, 31,
#        30, 25, 31, 28, 29, 30, 29, 31, 28, 30, 25, 28, 29, 30, 30, 31, 25,
# ...

# %%
print('shape before removing the outliers :',df.shape)

dsnew=df[(z<3).all(axis=1)]


print('Shape after removing the ouliers :',dsnew.shape)
# Out:
# shape before removing the outliers : (1470, 32)
# Shape after removing the ouliers : (1387, 32)

# %%
#### Percent Of Data Loss
(1470-1387)/1470*100
# Out:
# 5.646258503401361

# %%
dsnew
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      23          1               2        624           2                 0
# 1      31          0               1        113           1                 7
# 2      19          1               2        805           1                 1
# 3      15          0               1        820           1                 2
# 4       9          0               2        312           1                 1
# ...   ...        ...             ...        ...         ...               ...
# 1465   18          0               1        494           1                22
# 1466   21          0               2        327           1                 5
# 1467    9          0               2         39           1                 3
# 1468   31          0               1        579           2                 1
# 1469   16          0               2        336           1                 7
#
# ...

# %% [markdown]
# #### Lets handle the skewness

# %%
dsnew.skew()
# Out:
# Age                         0.472280
# Attrition                   1.805983
# BusinessTravel             -1.426774
# DailyRate                  -0.012403
# Department                  0.183919
# DistanceFromHome            0.954752
# Education                  -0.289024
# EducationField              0.544868
# EmployeeNumber              0.002331
# EnvironmentSatisfaction    -0.325285
# Gender                     -0.417296
# HourlyRate                 -0.030481
# JobInvolvement             -0.501401
# JobLevel                   -0.240467
# JobRole                    -0.386843
# JobSatisfaction            -0.345612
# MaritalStatus              -0.160952
# MonthlyIncome               0.112326
# MonthlyRate                 0.024344
# NumCompaniesWorked          0.075280
# OverTime                    0.954751
# PercentSalaryHike           0.800592
# PerformanceRating           1.931566
# RelationshipSatisfaction   -0.295686
# StockOptionLevel            0.962332
# ...

# %%
dsnew['YearsSinceLastPromotion']=np.cbrt(dsnew['YearsSinceLastPromotion'])

# %%
dsnew['YearsInCurrentRole']=np.cbrt(dsnew['YearsInCurrentRole'])

# %%
dsnew['TotalWorkingYears']=np.cbrt(dsnew['TotalWorkingYears'])

# %%
dsnew['JobLevel']=np.cbrt(dsnew['JobLevel'])

# %%
dsnew['NumCompaniesWorked']=np.cbrt(dsnew['NumCompaniesWorked'])

# %%
dsnew['NumCompaniesWorked']=np.sqrt(dsnew['YearsAtCompany'])

# %% [markdown]
# #### Training The Data

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
x=dsnew.drop('Attrition',axis=1)
y=dsnew['Attrition']

# %%
from sklearn.tree import DecisionTreeClassifier
maxAcc=0
maxRs=0
for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=i)
    DT=DecisionTreeClassifier()
    DT.fit(x_train,y_train)
    pred=DT.predict(x_test)
    accu=accuracy_score(y_test,pred)
    if accu>maxAcc:
        maxAcc=accu
        maxRs=1
print("Best accuracy -",maxAcc,'Best Random state = ',maxRs)
# Out:
# Best accuracy - 0.8231441048034934 Best Random state =  1

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=1)

# %%
from sklearn.svm import LinearSVC

clf = LinearSVC(random_state=1, tol=1e-5)

clf.fit(x_train, y_train.ravel())
# Out:
# LinearSVC(random_state=1, tol=1e-05)

# %%
pred=clf.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)

print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
# Out:
# Accuracy Score : 0.7685589519650655
# Classification Score :               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86       387
#            1       0.32      0.42      0.36        71
#
#     accuracy                           0.77       458
#    macro avg       0.60      0.63      0.61       458
# weighted avg       0.80      0.77      0.78       458

# %%
DTC=DecisionTreeClassifier()
DTC.fit(x_train,y_train)
pred=DTC.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)
confusion_matrix = confusion_matrix(y_test,pred)
print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
print('confusion Matrix :', confusion_matrix)
# Out:
# Accuracy Score : 0.7729257641921398
# Classification Score :               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86       387
#            1       0.30      0.34      0.32        71
#
#     accuracy                           0.77       458
#    macro avg       0.59      0.60      0.59       458
# weighted avg       0.79      0.77      0.78       458
#
# confusion Matrix : [[330  57]
#  [ 47  24]]

# %%
RF=RandomForestClassifier(n_estimators=1000,max_features='auto')
RF.fit(x_train,y_train)
pred=RF.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)

print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
# Out:
# Accuracy Score : 0.851528384279476
# Classification Score :               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       387
#            1       0.67      0.08      0.15        71
#
#     accuracy                           0.85       458
#    macro avg       0.76      0.54      0.53       458
# weighted avg       0.83      0.85      0.80       458

# %%
AD=AdaBoostClassifier(n_estimators=100,algorithm='SAMME')
AD.fit(x_train,y_train)
pred=AD.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)

print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
# Out:
# Accuracy Score : 0.8820960698689956
# Classification Score :               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93       387
#            1       0.72      0.39      0.51        71
#
#     accuracy                           0.88       458
#    macro avg       0.81      0.68      0.72       458
# weighted avg       0.87      0.88      0.87       458

# %%
LG=LogisticRegression()
LG.fit(x_train,y_train)
pred=LG.predict(x_test)
accu=accuracy_score(y_test,pred)
classification_score=classification_report(y_test,pred)

print('Accuracy Score :', accu)
print('Classification Score :', classification_score)
# Out:
# Accuracy Score : 0.8602620087336245
# Classification Score :               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.92       387
#            1       0.71      0.17      0.27        71
#
#     accuracy                           0.86       458
#    macro avg       0.79      0.58      0.60       458
# weighted avg       0.84      0.86      0.82       458

# %%
#### Cross Validation
from sklearn.model_selection import cross_val_score

# %%
print('Decission Tree :',cross_val_score(DTC,x,y,cv=5).mean())
# Out:
# Decission Tree : 0.7894631587149054

# %%
print('Random Forest :',cross_val_score(RF,x,y,cv=5).mean())
# Out:
# Random Forest : 0.8558060410877074

# %%
print('Adaboost Tree  :',cross_val_score(AD,x,y,cv=5).mean())
# Out:
# Adaboost Tree  : 0.8644443290133236

# %%
print('LOGISTIC REGRESSION  :',cross_val_score(LG,x,y,cv=5).mean())
# Out:
# LOGISTIC REGRESSION  : 0.842830428797756

# %% [markdown]
# #### Auc Roc

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

from sklearn.metrics import roc_auc_score

# %%
y_pred_prob=LG.predict_proba(x_test)[:,1]

# %%
y_pred_prob
# Out:
# array([0.08187611, 0.15173126, 0.02599348, 0.12029716, 0.01522544,
#        0.12418829, 0.2943627 , 0.36410697, 0.04417552, 0.05697742,
#        0.47673965, 0.06320479, 0.01491951, 0.14730617, 0.34190374,
#        0.17852346, 0.01623515, 0.07182105, 0.09045377, 0.05069704,
#        0.11926463, 0.04732226, 0.05289392, 0.5038957 , 0.07279179,
#        0.45970214, 0.52275036, 0.1698273 , 0.23090763, 0.07919321,
#        0.18727239, 0.26742999, 0.01954775, 0.1688612 , 0.24457074,
#        0.1585404 , 0.41039274, 0.06699355, 0.04376012, 0.04018318,
#        0.08256214, 0.12703003, 0.48820428, 0.15973947, 0.4100997 ,
#        0.49205562, 0.02554856, 0.28834898, 0.19125549, 0.16641988,
#        0.02064014, 0.23400473, 0.30029491, 0.40095584, 0.15762939,
#        0.31631917, 0.05252157, 0.04756022, 0.16585593, 0.03440314,
#        0.03666296, 0.41171902, 0.07647842, 0.02560024, 0.03723431,
#        0.00741195, 0.02200076, 0.06428043, 0.21745161, 0.17738251,
# ...

# %%
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)

# %%
thresholds
# Out:
# array([1.65632385, 0.65632385, 0.59719874, 0.59476555, 0.59425367,
#        0.58938808, 0.54832613, 0.54696099, 0.52713842, 0.52275036,
#        0.48820428, 0.47673965, 0.47158992, 0.44038534, 0.42876162,
#        0.4195096 , 0.41171902, 0.38426481, 0.38163869, 0.37828529,
#        0.37451738, 0.36482243, 0.36410697, 0.34829799, 0.34739298,
#        0.34694038, 0.34421206, 0.34190374, 0.33848758, 0.33347547,
#        0.33091359, 0.32780493, 0.32512163, 0.28202668, 0.27898319,
#        0.27343517, 0.27327046, 0.26742999, 0.26612324, 0.26579103,
#        0.26518372, 0.26406356, 0.26399934, 0.26064066, 0.25716455,
#        0.25705658, 0.25289222, 0.23557075, 0.23400473, 0.22946434,
#        0.22897006, 0.22120766, 0.21845499, 0.20712533, 0.20522898,
#        0.20010043, 0.20003169, 0.19278982, 0.19125549, 0.1836484 ,
#        0.18194613, 0.17992752, 0.17852346, 0.17566099, 0.17318635,
#        0.16249196, 0.16103353, 0.15229357, 0.15224386, 0.14689588,
# ...

# %%
fpr
# Out:
# array([0.        , 0.        , 0.        , 0.00516796, 0.00516796,
#        0.00775194, 0.00775194, 0.01033592, 0.01033592, 0.0129199 ,
#        0.0129199 , 0.01808786, 0.01808786, 0.02583979, 0.02583979,
#        0.03100775, 0.03100775, 0.04651163, 0.04651163, 0.04909561,
#        0.04909561, 0.05684755, 0.05684755, 0.06459948, 0.06459948,
#        0.06718346, 0.06718346, 0.07235142, 0.07235142, 0.08010336,
#        0.08010336, 0.08268734, 0.08268734, 0.12403101, 0.12403101,
#        0.13178295, 0.13178295, 0.1369509 , 0.1369509 , 0.13953488,
#        0.13953488, 0.14211886, 0.14211886, 0.1498708 , 0.1498708 ,
#        0.15245478, 0.15245478, 0.17571059, 0.17571059, 0.18604651,
#        0.18604651, 0.20671835, 0.20671835, 0.22739018, 0.22739018,
#        0.23514212, 0.23514212, 0.25064599, 0.25064599, 0.26098191,
#        0.26098191, 0.26356589, 0.26356589, 0.27131783, 0.27131783,
#        0.2997416 , 0.2997416 , 0.32816537, 0.32816537, 0.34883721,
# ...

# %%
tpr
# Out:
# array([0.        , 0.01408451, 0.04225352, 0.04225352, 0.05633803,
#        0.05633803, 0.11267606, 0.11267606, 0.14084507, 0.14084507,
#        0.1971831 , 0.1971831 , 0.21126761, 0.21126761, 0.25352113,
#        0.25352113, 0.28169014, 0.28169014, 0.29577465, 0.29577465,
#        0.32394366, 0.32394366, 0.35211268, 0.35211268, 0.36619718,
#        0.36619718, 0.38028169, 0.38028169, 0.3943662 , 0.3943662 ,
#        0.4084507 , 0.4084507 , 0.42253521, 0.42253521, 0.43661972,
#        0.43661972, 0.45070423, 0.45070423, 0.46478873, 0.46478873,
#        0.47887324, 0.47887324, 0.49295775, 0.49295775, 0.50704225,
#        0.50704225, 0.52112676, 0.52112676, 0.53521127, 0.53521127,
#        0.54929577, 0.54929577, 0.56338028, 0.56338028, 0.57746479,
#        0.57746479, 0.5915493 , 0.5915493 , 0.6056338 , 0.6056338 ,
#        0.61971831, 0.61971831, 0.63380282, 0.63380282, 0.64788732,
#        0.64788732, 0.66197183, 0.66197183, 0.67605634, 0.67605634,
# ...

# %%
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Logistic Regression')
plt.xlabel('False Positive rate')
plt.ylabel('True Postive rate')
plt.title('Logistic Regression')
plt.show()

# %%
#### Postive One

# %% [markdown]
# #### Random Forest is Best Model

# %% [markdown]
# #### Hyper Parameter Tunning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter ={'max_depth':np.arange(2,10),
           'criterion':['gini', 'entropy'],
           'max_features':['sqrt','log2','auto']}

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameter,cv=5)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                          'max_features': ['sqrt', 'log2', 'auto']})

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 3, 'splitter': 'random'}

# %%
Final_model=RandomForestClassifier(criterion='gini',max_depth=3,max_features='auto')
Final_model.fit(x_train,y_train)
pred=Final_model.predict(x_test)
accu=accuracy_score(y_test,pred)
print(accu*100)
# Out:
# 84.49781659388647
